# %%
# !git clone https://github.com/facebookresearch/ImageBind.git
# !pip install git+https://github.com/facebookresearch/pytorchvideo.git@28fe037d212663c6a24f373b94cc5d478c8c1a1d timm==0.6.7 ftfy regex einops fvcore decord==0.6.0
# Out:
# Cloning into 'ImageBind'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (66/66), done.s:  57% (38/66)
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 117 (delta 45), reused 34 (delta 33), pack-reused 51
# Receiving objects: 100% (117/117), 2.64 MiB | 3.60 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# ...
#   Cloning https://github.com/facebookresearch/pytorchvideo.git (to revision 28fe037d212663c6a24f373b94cc5d478c8c1a1d) to /private/var/folders/fr/d_m1dl4968d6dkzh1_1hy4jh0000gn/T/pip-req-build-pr3vzn5i
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/pytorchvideo.git /private/var/folders/fr/d_m1dl4968d6dkzh1_1hy4jh0000gn/T/pip-req-build-pr3vzn5i
#   Running command git rev-parse -q --verify 'sha^28fe037d212663c6a24f373b94cc5d478c8c1a1d'
#   Running command git fetch -q https://github.com/facebookresearch/pytorchvideo.git 28fe037d212663c6a24f373b94cc5d478c8c1a1d
# ...

# %%
# !pip install torch
# !pip install ftfy
# !pip install timm
# !pip install /Users/aviajmera/Downloads/Clustering/Audio Embedding/ImageBind/requirements.txt
# Out:
# ...
# ERROR: Invalid requirement: '/Users/aviajmera/Downloads/Clustering/Audio'
# Hint: It looks like a path. File '/Users/aviajmera/Downloads/Clustering/Audio' does not exist.

# %%
# %cd /Users/aviajmera/Downloads/Clustering/Audio Embedding/ImageBind
# Out:
# /Users/aviajmera/Downloads/Clustering/Audio Embedding/ImageBind

# %%
import IPython
from PIL import Image


IPython.display.Audio("/Users/aviajmera/Downloads/Clustering/Audio Embedding/IMG_9809.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %cd /Users/aviajmera/Downloads/Clustering/Audio Embedding/ImageBind
# Out:
# /Users/aviajmera/Downloads/Clustering/Audio Embedding/ImageBind

# %%
# !pip install einops

# %%
import torch
import torchvision
from imagebind import data
from models import imagebind_model
from models.imagebind_model import ModalityType


device = "cuda:0" if torch.cuda.is_available() else "cpu"
device
# Out:
# /Users/aviajmera/anaconda3/lib/python3.11/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# /Users/aviajmera/anaconda3/lib/python3.11/site-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /Users/aviajmera/anaconda3/lib/python3.11/site-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
# ...

# %%
model = imagebind_model.imagebind_huge(pretrained=True)
model.eval()
model.to(device)
# Out:
# ...
# 100%|██████████| 4.47G/4.47G [02:38<00:00, 30.3MB/s]
# ImageBindModel(
#   (modality_preprocessors): ModuleDict(
#     (vision): RGBDTPreprocessor(
#       (cls_token): tensor((1, 1, 1280), requires_grad=True)
#
#       (rgbt_stem): PatchEmbedGeneric(
#         (proj): Sequential(
#           (0): PadIm2Video()
#           (1): Conv3d(3, 1280, kernel_size=(2, 14, 14), stride=(2, 14, 14), bias=False)
#         )
#       )
#       (pos_embedding_helper): SpatioTemporalPosEmbeddingHelper(
#         (pos_embed): tensor((1, 257, 1280), requires_grad=True)
#
#       )
#     )
#     (text): TextPreprocessor(
#       (pos_embed): tensor((1, 77, 1024), requires_grad=True)
#       (mask): tensor((77, 77), requires_grad=False)
#
#       (token_embedding): Embedding(49408, 1024)
#     )
#     (audio): AudioPreprocessor(
#       (cls_token): tensor((1, 1, 768), requires_grad=True)
#
#       (rgbt_stem): PatchEmbedGeneric(
# ...

# %%
inputs = {
    ModalityType.AUDIO: data.load_and_transform_audio_data(["/Users/aviajmera/Downloads/Clustering/Audio Embedding/IMG_9809.mp3"], device),
}

with torch.no_grad():
    embeddings = model(inputs)

# %%
print(
    "Audio x Text: ",
    embeddings[ModalityType.AUDIO]
)
# Out:
# Audio x Text:  tensor([[-0.3368,  0.0267, -0.5883,  ...,  0.3499, -0.2083, -0.3954]])
